# %%
url="https://i.imgur.com/VGPeJ6s.jpg"
# Out:
# "https://i.imgur.com/VGPeJ6s.jpg"

# %%
download(url, "philip.jpg")
# Out:
# "philip.jpg"

# %%
using Images
philip = load("philip.jpg")
# Out:
# 3675×2988 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.2,0.149,0.082)    …  RGB{N0f8}(0.722,0.741,0.757)
#  RGB{N0f8}(0.2,0.149,0.082)       RGB{N0f8}(0.722,0.741,0.757)
#  RGB{N0f8}(0.2,0.149,0.082)       RGB{N0f8}(0.718,0.737,0.753)
#  RGB{N0f8}(0.204,0.153,0.086)     RGB{N0f8}(0.714,0.733,0.749)
#  RGB{N0f8}(0.204,0.153,0.086)     RGB{N0f8}(0.714,0.733,0.749)
#  RGB{N0f8}(0.204,0.153,0.086)  …  RGB{N0f8}(0.71,0.729,0.745)
#  RGB{N0f8}(0.208,0.157,0.09)      RGB{N0f8}(0.706,0.725,0.741)
#  RGB{N0f8}(0.208,0.157,0.09)      RGB{N0f8}(0.706,0.725,0.741)
#  RGB{N0f8}(0.149,0.118,0.043)     RGB{N0f8}(0.714,0.733,0.749)
#  RGB{N0f8}(0.161,0.129,0.055)     RGB{N0f8}(0.714,0.733,0.749)
#  ⋮                             ⋱
#  RGB{N0f8}(0.831,0.729,0.529)     RGB{N0f8}(0.737,0.624,0.404)
#  RGB{N0f8}(0.812,0.71,0.51)       RGB{N0f8}(0.741,0.627,0.408)
#  RGB{N0f8}(0.792,0.69,0.49)       RGB{N0f8}(0.733,0.62,0.4)
#  RGB{N0f8}(0.784,0.682,0.482)     RGB{N0f8}(0.737,0.624,0.404)
# ...
